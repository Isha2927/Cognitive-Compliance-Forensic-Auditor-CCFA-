# %%
import pandas as pd

nodes = pd.read_csv("Neo4j dataset/nodes.csv")
print(nodes.columns)
print(nodes.head())
# Out:
# Index(['a.id', 'a.pageRankScore', 'a.communityId'], dtype='object')
#    a.id  a.pageRankScore  a.communityId
# 0  6456         0.650782           1137
# 1  7516         0.397279           2491
# 2  2445         0.536375           4889
# 3  2576         0.445227           7569
# 4  3524         0.690119           4889

# %%
import pandas as pd

edges = pd.read_csv("Neo4j dataset/edges.csv")
print(edges.columns)
print(edges.head())
# Out:
# Index(['src', 'dst', 't.amount', 't.isFraud'], dtype='object')
#     src   dst  t.amount  t.isFraud
# 0  6456  9069    465.05          0
# 1  6456  9069    465.05          0
# 2  6456  9069    465.05          0
# 3  6456  9069    465.05          0
# 4  6456  9069    465.05          0
